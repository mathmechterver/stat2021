# %% [markdown]
# # 9. Критерии однородности.

# %% [markdown]
# Есть 2 выборки $X_{[n]}$ и $Y_{[m]}$, нужно понять взяты ли они из одного распределения

# %% [markdown]
# ## Критерий равенства матожиданий
#
# [Теория](www.mathprofi.ru/proverka_statisticheskih_gipotez.html)
#
# Статистика для равенства матожиданий
# $Z = \frac{(\overline{X} - \overline{Y}) - (a_X - a_Y)}{\sqrt{\mathbb{D}(\overline{X} - \overline{Y})}} = \frac{(\overline{X} - \overline{Y})}{\sqrt{\mathbb{D}(\overline{X} - \overline{Y})}}$ при выполнении $H_0: a_X = a_Y$
#
# * Если дисперсии выборок известны точные, то $Z = \frac{(\overline{X} - \overline{Y})}{\sqrt{\frac{\sigma_X^2}{n} + \frac{\sigma_Y^2}{m}}} \sim \mathcal{N}(0,1)$
#
# * Если дисперсии выборок неизвестны, то $Z = \frac{(\overline{X} - \overline{Y})}{\sqrt{\frac{s_X^2}{n} + \frac{s_Y^2}{m}}}\sim T(K)$, где $K = \frac{\Big(\frac{s_X^2}{n} + \frac{s_Y^2}{m}\Big)^2}{\frac{(s_X^2/n)^2}{n-1} + \frac{(s_Y^2/m)^2}{m-1}}$

# %% [markdown]
# ## Критерий равенства дисперсий (Критерий Фишера)
#
# [Теория](https://tvims.nsu.ru/chernova/ms/lec/node51.html#SECTION000870)
#
# Пусть у нас есть 2 выборки. Попробуем сравнить их дисперсии.
#
# Пусть $H_0: \sigma_1^2 = \sigma_2^2$
#
# Возьмем $\chi^2$ статистики каждой:
#
# $Z_1 = \frac{(n-1)s_{X}^2}{\sigma_1^2} \sim \chi^2(n-1)$ и $Z_2 = \frac{(m-1)s_{Y}^2}{\sigma_2^2} \sim \chi^2(m-1)$
#
# Тогда возьмем статистику Фишера:
#
# $$Z_3 = \frac{Z_1}{Z_2}\frac{m-1}{n-1} \sim F(n-1, m-1)$$
#
# P.S. Действительно, потому что $\frac{\sigma_1^2}{\sigma_2^2} = 1$ при выполнении $H_0$

# %% [markdown]
# #### Мразь 3
#
# Пусть $Y_{1},Y_{2}$ — две независимые случайные величины, имеющие распределение хи-квадрат: $ Y_{i}\sim \chi ^{2}(d_{i})$, где $ d_{i}\in \mathbb {N} ,\;i=1,2$ . Тогда распределение случайной величины
#
# $ F={\frac {Y_{1}/d_{1}}{Y_{2}/d_{2}}}$ называется распределением Фишера со степенями свободы $d_{1}$ и $d_{2}$. Пишут $ F\sim \mathrm{F}(d_{1},d_{2})$

# %% [markdown]
# ## Однофакторный дисперсионный анализ
#
# [Теория](https://studme.org/289829/matematika_himiya_fizik/odnofaktornyy_dispersionnyy_analiz)

# %% [markdown]
# Пусть есть куча выборок: $X_{[n_1]}^1, X_{[n_2]}^2, \ldots, X_{[n_k]}^k$ c единой дисперсией $\sigma^2$
#
# Хотим проверить гипотезы:
# * $H_0: \mu_1 = \ldots = \mu_k$
# * $H_1: \exists t,s:$ $\mu_t \neq \mu_s$

# %% [markdown]
# $N = \sum_{i=1}^{k}n_i$
#
# $\overline{X^j} = \frac{1}{n_j}\sum_{i=1}^{n_j}X^j_{i}$
#
# $\overline{X} = \frac{1}{N}\sum_{j=1}^{k}\sum_{i=1}^{n_j}X^j_{i}$

# %% [markdown]
# $S = \sum_{j=1}^{k}\sum_{i=1}^{n_j}(X^j_{i} - \overline{X})^2 = Q_1 + Q_2$
#
# $Q_1 = \sum_{j=1}^{k}\sum_{i=1}^{n_j}(X^j_{i} - \overline{X^j})^2$
#
# $Q_2 = \sum_{j=1}^{k}n_j(\overline{X} - \overline{X^j})^2$

# %% [markdown]
# Нетривиальные утверждения:
#
# * $\frac{Q_1}{\sigma^2} \sim \chi^2(N-k)$ всегда
# * $\frac{Q_2}{\sigma^2} \sim \chi^2(k-1)$ если выполняется $H_0$
#
# Тогда
#
# $\frac{Q_2}{Q_1}\frac{N-k}{k-1} \sim F(k-1, N-k)$

# %% [markdown]
# # Задачи на пару

# %% [markdown]
# 1. Докажите, что статистика для критерия равенства матожиданий $Z = \frac{(\overline{X} - \overline{Y})}{\sqrt{\mathbb{D}(\overline{X} - \overline{Y})}}$ распределена как $\mathcal{N}(0,1)$ если дисперсии выборок известны

# %% [markdown]
# 2. Есть выборка продукции A и B:
#
# * $n_A = 16$, $\overline{X}_A = 37.5$, $s^2_A = 1.21$
# * $n_B = 25$, $\overline{X}_B = 36.8$, $s^2_B = 1.44$.
#
# С уровнем значимости 0.05 проверьте гипотезы о равенстве дисперсии и матожидания.

# %% [markdown]
# 3. Набор критической частоты мерцания света, при которой глаз перестает воспринимать мерцание и свет становится непрерывным. Проверим, есть ли зависимость между цветом радужки глаза критической частотой с помощью однофакторного дисперсионного анализ. Доверительный интервал 0.95
# * Brown: 26.8, 27.9, 23.7, 25, 26.3, 24.8, 25.7, 24.5
# * Green: 26.4, 26.2, 28, 26.9, 29.1
# * Blue : 25.7, 27.2, 29.9, 28.5, 29.4, 28.3

# %%
import numpy as np
np.array([26.4, 26.2, 28, 26.9, 29.1]).mean()
# Out:
# 27.32

# %%
from scipy.stats import f

f.ppf(0.975, 16, 2)
# Out:
# 39.43542317109749

# %% [markdown]
# # Задачи на дом

# %% [markdown]
# 1. (1.25) [ref](https://stepik.org/lesson/26463/step/6?unit=8346)
#
# Два токарных автомата изготавливают детали по одному чертежу. Из продукции первого станка было отобрано $9$ деталей, а из продукции второго - $11$ деталей. Выборочные дисперсии контролируемого  размера, определенные по этим выборкам $5.9мкм^2$ и $23.3мкм^2$. Проверьте гипотезу о равенстве дисперсий при уровне значимости $0.01$, если альтернативная гипотеза утверждает, что дисперсии не равны. (предполагаем, что контролируемый размер подчиняется нормальному закону распределения)

# %% [markdown]
# 2. (1.25) [ref](https://stepik.org/lesson/26463/step/9?unit=8346)
#
# Можно ли считать, что средние двух нормально распределенных совокупностей равны, если выборочные средние и дисперсии, вычисленные по двум выборкам объема 16 и 9 равны соответственно $\bar x_1=12.57$, $D^*_1=0.91$, $\bar x_2=11.87$, $D^*_2=1.51$
#
# Известно, что дисперсии не  равны. Уровень значимости  $0.02$
#
# Найдите закон распределения статистики критерия.
#
# Найдите p-значение и примите статистическое решение

# %% [markdown]
# 3. (1.25) [ref](https://stepik.org/lesson/27765/step/2?unit=9041) Сравните среднюю продолжительность успешных проходов в 10 матчах по рэгби (`rugby.txt`)
#
# Уровень значимости 0.05. Предполагаем, что продолжительность успешных проходов имеет нормальное распределение.
#
# Найдите статистику критерия однофакторного дисперсионного анализа и примите статистическое решение: все ли матожидания равны или нет?

# %% [markdown]
# 4. (1.25) [ref](https://stepik.org/lesson/26284/step/5?unit=8172)
#
#
# Время химической реакции при различном содержании катализатора распределилось следующим образом
#
# * 5%: 5.9, 6.0, 7.0, 6.5, 5.5, 7.0, 8.1, 7.5, 6.2, 6.4, 7.1, 6.9
# * 10%: 4.0, 5.1, 6.2, 5.3, 4.5, 4.4, 5.3, 5.4,5.6,5.2
# * 15%: 8.2, 6.8, 8.0, 7.5, 7.2, 7.9, 8.1, 8.5, 7.8, 8.1
#
# Выборки получены из нормально распределенных генеральных совокупностей с равными дисперсиями. Проверить гипотезу о равенстве средних. Уровень значимости принять равным 0.1.
# * Найдите значение статистики, которая является точечной оценкой дисперсии независимо от того, верна нулевая гипотеза или нет.
# * Найдите выборочное значение статистики критерия и примите статистическое решение

# %% [markdown]
# # Гробы

# %% [markdown]
# 1. (2) Докажите, что статистика для критерия равенства матожиданий $Z = \frac{(\overline{X} - \overline{Y})}{\sqrt{\mathbb{D}(\overline{X} - \overline{Y})}}$ распределена как $T(K)$ если дисперсии выборок неизвестны и найдите $K$

# %% [markdown]
# 2. Докажите нетривиальные утверждения
# * (2) $\frac{Q_1}{\sigma^2} \sim \chi^2(N-k)$ всегда
# * (2) $\frac{Q_2}{\sigma^2} \sim \chi^2(k-1)$ если выполняется $H_0$
