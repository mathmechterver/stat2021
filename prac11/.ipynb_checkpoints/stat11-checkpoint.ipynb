# %% [markdown]
# # 11. Понятие случайного процесса. Пуассоновский процесс. Случайное блуждание.

# %% [markdown]
# $(\Omega, \mathcal{F}, \mathbb{P})$ - вероятностное пространство, T - мн-во моментов времени
#
# $\{\xi_t\}_{t\in T}$ - семейство случайных величин
#
# $\xi_t(\omega) = f(t, \omega)$

# %% [markdown]
# ### Пуассоновский процесс
#
# $T = [0, +\infty)$ $\xi_t$ - число событий на промежутке $[0,t]$
# 1. За конечное время происходит лишь конечное число событий
# 2. Появление нескольких событий одновременно - невозможно
# 3. На непересекающихся промежутках количества событий - независимы
# $\xi_{t_1}, \xi_{t_2} - \xi_{t_1}, \ldots, \xi_{t_n} - \xi_{t_{n-1}}$
# 4. Количество зарегестрированных событий зависит от только длины промежутка ($\xi_{t+h} - \xi_t$ не зависит от $t$)

# %% [markdown]
# 1. $\frac{1}{h}P(\xi_{t+h} - \xi_{t} > 1) = 0$
# [Доказательство](https://stepik.org/lesson/254732/step/3?unit=234940)

# %% [markdown]
# 2. $P(\xi_{t+h} - \xi_t > 0) = 1-e^{-\lambda h} = \lambda h + o(h)$
# [Доказательство](https://stepik.org/lesson/254732/step/4?unit=234940)

# %% [markdown]
# 3. $P(\xi_t = 0) = \frac{(\lambda t)^k}{k!}e^{-\lambda t}$
# [Доказательство](https://stepik.org/lesson/254732/step/5?unit=234940)

# %% [markdown]
# # Задачи
#
# 1. Дан пуассоновский процесс с интенсивностью $\lambda=b$. Найдите $P(\xi_t \text{ --- четно})$
#
# 2. Дан пуассоновский процесс с интенсивностью $\lambda=\dfrac{4}{3}$ Найдите $P(\xi_5=3|\xi_2=1)$. В ответе приведите найденную вероятность в виде десятичной дроби, в случае необходимости округленной до трех знаков после запятой.
#
# 3. Дан пуассоновский процесс с интенсивностью $\lambda=2$. Найдите $\mathbb{E}(\xi_5\xi_2)$. В ответе приведите найденное математическое ожидание в виде десятичной дроби, в случае необходимости округленной до трех знаков после запятой.
#
# 4. Рассмотрим пуассоновский процесс с интенсивностью $\lambda=b$. Пусть случайная величина $\tau_1$ обозначает момент времени, когда была зарегистрирована первая частица. Найдите $P(\tau_1\leqslant s\,|\,\xi_t=1)$, если $0<s<t0<s<t$.
#
# 5. Рассмотрим пуассоновский процесс с интенсивностью $\lambda=1,\!5$. Пусть случайная величина $\tau_3$ обозначает момент времени, когда была зарегистрирована третья частица. Найдите $P(\tau_3\leqslant 2)$. В ответе приведите найденную вероятность в виде десятичной дроби, в случае необходимости округленной до трех знаков после запятой.
#
# 6. Рассмотрим пуассоновский процесс с интенсивностью $\lambda$. Пусть случайная величина $\tau_k$ обозначает момент времени, когда была зарегистрирована $k$-я частица. Тогда
# $$P(\tau_1>t)=P(\xi_t=0)=\frac{(\lambda t)^0}{0!} e^{-\lambda t}=e^{-\lambda t}$$
# Следовательно,
# $$F_{\tau_1}(t)=P(\tau_1\leqslant t)=1-P(\tau_1>t)=1-e^{-\lambda t} $$.
# Таким образом, $\tau_1$ имеет экспоненциальное распределение с параметром $\lambda$.
#
# Найдите математическое ожидание и дисперсию $\tau_k$
# В качестве ответа приведите $\mathbb{E}\tau_k$ $\mathbb{D}\tau_k$ для $\lambda=4$ и $k=6$ в виде десятичных дробей, разделенных пробелом.
#
# 7. Рассмотрим пуассоновский процесс с интенсивностью \lambda=bλ=b и независимые одинаково распределенные случайные величины $\eta_n$ c математическим ожиданием aa и дисперсией dd. Пусть в момент времени $\tau_n$  (см. предыдущую задачу) на сервер приходит $\eta_n$ запросов. Случайная величина $\zeta_t$ — количество запросов, пришедших до момента времени $t$.
# Найдите
# * $\mathbb{E}\zeta_t$,
# * $\mathbb{D}\zeta_t$
#
# 8. Два редактора читают корректуру пятисотстраничной книги. Первый редактор нашел 130130 опечаток, второй нашел 150150. Оказалось, что 100100 опечаток нашли оба редактора. Опечатки встречаются по пуассоновскому процессу с некоторой неизвестной интенсивностью на страницу, а редакторы находят опечатки с фиксированными неизвестными вероятностями. Какое следует ожидать количество опечаток, которые не нашел ни один из редакторов? В ответе приведите найденное число в виде десятичной дроби, в случае необходимости округленной до трех знаков после запятой.
#
# 9. Чудеса случаются по пуассоновскому процессу с интенсивностью $\lambda>1$. Мудрец играет в следующую игру. Когда происходит чудо, он либо заявляет, что это чудо было последним в этом году, либо продолжает ждать следующего чуда. Если он угадает, то получит много денег, если нет (т.е. после его заявления случится новое чудо или он вообще не сделает этого заявления до конца года), то он будет казнен. Мудрец решил действовать по следующей стратегии: он заявит о чуде, которое произойдет после некоторого времени $s$. Он выбирает оптимальное $s$ для этой стратегии. С какой вероятностью он выиграет? В ответе приведите найденную вероятность в виде десятичной дроби, в случае необходимости округленной до трех знаков после запятой.
#
# 10. Пассажиры прибывают на железнодорожную станцию по пуассоновскому процессу с интенсивностью $\lambda=b$. В момент времени $0$ пассажиров на станции нет, в момент времени tt отправится поезд. Случайная величина $\eta$ — общее время ожидания всех пассажиров, прибывших до отправления поезда. Найдите $\mathbb{E}\eta$.
#
# Указание. Поймите что нужно проинтегрировать, чтобы получилась $\eta$.
